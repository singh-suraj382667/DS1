# %% [markdown]
# Here going to make a model that can predict whether a male or female is suffering with heart diease or not on the basis of some coditions such as Chest pain,Resting BP,Chollestrol,FastingBP and etc.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Here reading the dataset

# %%
df = pd.read_csv("C:\\Users\\ASUS\\Downloads\\data sets\\heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# Checking the nan values in the dataset

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# Let's check no of zero's in ever column

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
clist = ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
       'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope']

# %%
def zeros(df,i):
    return df[i][df[i]==0].value_counts()

# %% [markdown]
# Here some columns are having zeor value which is not right , b'c if a person having Resting BP zero , it means he is not alive. we have to change it with somee appropriate vslues.

# %%
for i in clist:
    print(zeros(df,i))
# Out:
# Series([], Name: Age, dtype: int64)
# Series([], Name: Sex, dtype: int64)
# Series([], Name: ChestPainType, dtype: int64)
# 0    1
# Name: RestingBP, dtype: int64
# 0    172
# Name: Cholesterol, dtype: int64
# 0    704
# Name: FastingBS, dtype: int64
# Series([], Name: RestingECG, dtype: int64)
# Series([], Name: MaxHR, dtype: int64)
# Series([], Name: ExerciseAngina, dtype: int64)
# 0.0    368
# Name: Oldpeak, dtype: int64
# Series([], Name: ST_Slope, dtype: int64)

# %% [markdown]
# Here the zero's are being replaced with mean value of that column

# %%
def fillzeros(df,i):
    if type(df[i][0])!=str:
        df [i]=df[i].replace(0, df[i].mean())
    else:
        pass

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
clist = ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
       'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope']

# %%
for i in clist:
    fillzeros(df,i)

# %% [markdown]
# Here again checking the zeros after replacement

# %%
for i in clist:
    print(zeros(df,i))
# Out:
# Series([], Name: Age, dtype: int64)
# Series([], Name: Sex, dtype: int64)
# Series([], Name: ChestPainType, dtype: int64)
# Series([], Name: RestingBP, dtype: int64)
# Series([], Name: Cholesterol, dtype: int64)
# Series([], Name: FastingBS, dtype: int64)
# Series([], Name: RestingECG, dtype: int64)
# Series([], Name: MaxHR, dtype: int64)
# Series([], Name: ExerciseAngina, dtype: int64)
# Series([], Name: Oldpeak, dtype: int64)
# Series([], Name: ST_Slope, dtype: int64)

# %% [markdown]
# As we know that a machine learning model dosen't understand categorical data . So we need to encode all the categorical data to the numerical data .

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0        289.0   0.233115     Normal
# 1     49   F           NAP      160.0        180.0   0.233115     Normal
# 2     37   M           ATA      130.0        283.0   0.233115         ST
# 3     48   F           ASY      138.0        214.0   0.233115     Normal
# 4     54   M           NAP      150.0        195.0   0.233115     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      110.0        264.0   0.233115     Normal
# 914   68   M           ASY      144.0        193.0   1.000000     Normal
# 915   57   M           ASY      130.0        131.0   0.233115     Normal
# 916   57   F           ATA      130.0        236.0   0.233115        LVH
# 917   38   M           NAP      138.0        175.0   0.233115     Normal
#
#      MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease
# ...

# %%
def outliersiqr(df,i):
    if type(df[i][0])!=str:
        q1= df[i].quantile(0.25)
        q3= df[i].quantile(0.75)
        iqr = q3-q1
        low = q1 - (1.5*iqr)
        upp = q3 + (1.5*iqr)
        vl = df[(df[i]>=low) & (df[i]<=upp)]
        df[i] = df[i].apply(lambda x : df[i].mean() if x<= low else df[i].mean() if x>=upp else x )

# %%
def outliersmst(df,i):
    if type(df[i][0])!=str:
        m= df[i].mean()
        sd = df[i].std()
        low = m - (3*sd)
        upp = m + (3*sd)
        ovalid = df[df[i]>=low & (df[i]<= upp)]
        df[i] = df[i].apply(lambda x : df[i].mean() if x<= low else df[i].mean() if x>=upp else x )

# %%
for i in df.columns:
    if type(df[i][0])!=str:
        print(df[i].skew())
# Out:
# -0.19593302867569365
# 0.6075508374550895
# 1.5311149643742612
# 1.2644841750727025
# -0.14435941846180994
# 1.2666167717575862
# -0.21508633825088655

# %%
def skew():
    if type(df[i][0])!=str:
        if (df[i].skew()<=0.8) or (df[i].skew()>=-0.8):
            outliersmst(df,i)
        else:
            outliersiqr(df,i)

# %%
for i in df.columns:
    if type(df[i][0])!=str:
        print(df[i].skew())
# Out:
# -0.19593302867569365
# 0.6075508374550895
# 1.5311149643742612
# 1.2644841750727025
# -0.14435941846180994
# 1.2666167717575862
# -0.21508633825088655

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0        289.0   0.233115     Normal
# 1     49   F           NAP      160.0        180.0   0.233115     Normal
# 2     37   M           ATA      130.0        283.0   0.233115         ST
# 3     48   F           ASY      138.0        214.0   0.233115     Normal
# 4     54   M           NAP      150.0        195.0   0.233115     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      110.0        264.0   0.233115     Normal
# 914   68   M           ASY      144.0        193.0   1.000000     Normal
# 915   57   M           ASY      130.0        131.0   0.233115     Normal
# 916   57   F           ATA      130.0        236.0   0.233115        LVH
# 917   38   M           NAP      138.0        175.0   0.233115     Normal
#
#      MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one = OneHotEncoder(drop = "first")

# %%
def encode(df,i):
    if type(df[i][0])==str:
        d =one.fit_transform(df[[i]]).toarray()
        cname = one.categories_
        dd = pd.DataFrame(d, columns=cname[0][1:: ], dtype = int)
        fdf= pd.concat([df,dd], axis = 1)
        ffdf = fdf.drop([i], axis = 1)
        return ffdf

# %%
clist
# Out:
# ['Age',
#  'Sex',
#  'ChestPainType',
#  'RestingBP',
#  'Cholesterol',
#  'FastingBS',
#  'RestingECG',
#  'MaxHR',
#  'ExerciseAngina',
#  'Oldpeak',
#  'ST_Slope']

# %%
for i in clist:
    df1=encode(df,i)

# %%
df1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0        289.0   0.233115     Normal
# 1     49   F           NAP      160.0        180.0   0.233115     Normal
# 2     37   M           ATA      130.0        283.0   0.233115         ST
# 3     48   F           ASY      138.0        214.0   0.233115     Normal
# 4     54   M           NAP      150.0        195.0   0.233115     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      110.0        264.0   0.233115     Normal
# 914   68   M           ASY      144.0        193.0   1.000000     Normal
# 915   57   M           ASY      130.0        131.0   0.233115     Normal
# 916   57   F           ATA      130.0        236.0   0.233115        LVH
# 917   38   M           NAP      138.0        175.0   0.233115     Normal
#
#      MaxHR ExerciseAngina   Oldpeak  HeartDisease  Flat  Up
# ...

# %% [markdown]
# getting some problem in onehot encoding . So let's do encoding with dummivariable

# %%
df2= pd.get_dummies(df, drop_first = True)

# %%
df2
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR   Oldpeak  HeartDisease  \
# 0     40      140.0        289.0   0.233115    172  0.887364             0
# 1     49      160.0        180.0   0.233115    156  1.000000             1
# 2     37      130.0        283.0   0.233115     98  0.887364             0
# 3     48      138.0        214.0   0.233115    108  1.500000             1
# 4     54      150.0        195.0   0.233115    122  0.887364             0
# ..   ...        ...          ...        ...    ...       ...           ...
# 913   45      110.0        264.0   0.233115    132  1.200000             1
# 914   68      144.0        193.0   1.000000    141  3.400000             1
# 915   57      130.0        131.0   0.233115    115  1.200000             1
# 916   57      130.0        236.0   0.233115    174  0.887364             1
# 917   38      138.0        175.0   0.233115    173  0.887364             0
#
# ...

# %% [markdown]
# Now let's split the dataset into dependent and independent columns

# %%
X = df2.drop("HeartDisease", axis =1)

# %%
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR   Oldpeak  Sex_M  \
# 0     40      140.0        289.0   0.233115    172  0.887364      1
# 1     49      160.0        180.0   0.233115    156  1.000000      0
# 2     37      130.0        283.0   0.233115     98  0.887364      1
# 3     48      138.0        214.0   0.233115    108  1.500000      0
# 4     54      150.0        195.0   0.233115    122  0.887364      1
# ..   ...        ...          ...        ...    ...       ...    ...
# 913   45      110.0        264.0   0.233115    132  1.200000      1
# 914   68      144.0        193.0   1.000000    141  3.400000      1
# 915   57      130.0        131.0   0.233115    115  1.200000      1
# 916   57      130.0        236.0   0.233115    174  0.887364      0
# 917   38      138.0        175.0   0.233115    173  0.887364      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0                    1                  0                 0
# ...

# %%
y = df2["HeartDisease"]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %% [markdown]
# let's split the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y, test_size = 0.20)

# %%
Xtrain.shape, Xtest.shape, ytrain.shape,  ytest.shape
# Out:
# ((734, 15), (184, 15), (734,), (184,))

# %%
from xgboost import XGBClassifier

# %%
xg = XGBClassifier()

# %%
xg.fit(Xtrain,ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
xg.score(Xtest,ytest)
# Out:
# 0.8695652173913043

# %% [markdown]
# let's do scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
ss.fit(Xtrain)
# Out:
# StandardScaler()

# %%
Xtr_ss = ss.transform(Xtrain)

# %%
Xte_ss = ss.transform(Xtest)

# %%
xgs = XGBClassifier()

# %%
xgs.fit(Xtr_ss,ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
xgs.score(Xte_ss,ytest)
# Out:
# 0.8695652173913043

# %% [markdown]
# Let's do cross validation

# %%
sd = StandardScaler()

# %%
xtr = sd.fit_transform(X)

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
gs = XGBClassifier()

# %%
kf = KFold(n_splits= 10)

# %%
score = cross_val_score(gs,xtr,y,cv = kf).mean()

# %%
score
# Out:
# 0.8429646440516005

# %% [markdown]
# Let's do it with pipe line

# %%
from sklearn.pipeline import make_pipeline

# %%
pipe = make_pipeline(StandardScaler(),XGBClassifier())

# %%
pipe.fit(Xtr_ss,ytrain)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                gamma=0, gpu_id=-1, grow_policy='depthwise',
#                                importance_type=None, interaction_constraints='',
#                                learning_rate=0.300000012, max_bin=256,
#                                max_cat_to_onehot=4, max_delta_step=0,
#                                max_depth=6, max_leaves=0, min_child_weight=1,
#                                missing=nan, monotone_constraints='()',
#                                n_estimators=100, n_jobs=0, num_parallel_tree=1,
# ...

# %%
pipe.score(Xte_ss,ytest)
# Out:
# 0.8695652173913043

# %%
kf = KFold(n_splits= 10)

# %%
cross_val_score(pipe,X,y,cv= kf).mean()
# Out:
# 0.8429646440516005
